# %%
import pandas as pd
import zipfile
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\monika'

# %%
os.listdir()
# Out:
# ['.android',
#  '.AndroidStudio2.2',
#  '.AndroidStudio2.3',
#  '.AndroidStudio3.1',
#  '.AndroidStudioPreview3.0',
#  '.gradle',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.python_history',
#  '3D Objects',
#  'Amazon_Cleaned.csv',
#  'Amazon_Cleaned.xlsx',
#  'Amazon_Cleaned_1.csv',
#  'Amazon_data_cleaning.ipynb',
#  'AndroidStudioProjects',
#  'AppData',
#  'Application Data',
#  'Blinkit_Cleaned.ipynb',
#  'Blinkit_Dataset',
#  'bootcamp1.ipynb',
#  'Contacts',
#  'Cookies',
#  'customers_clean.csv',
#  'delivery_clean.csv',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'feedback_clean.csv',
#  'HR_ANALYTICS-CLEAR.ipynb',
#  'HR_Analytics_Cleaned.csv',
#  'HR_Analytics_Final.csv',
#  'inventoryNew_clean.csv',
#  'inventory_clean.csv',
#  'learning python basic .ipynb',
#  'Links',
#  'Local Settings',
#  'marketing_clean.csv',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
# ...

# %%
with zipfile.ZipFile(r"C:\Users\monika\Downloads\archive(3).zip") as zip_ref:
    zip_ref.extractall("Blinkit_Dataset")

# %%
os.listdir("Blinkit_Dataset")
# Out:
# ['blinkit_customers.csv',
#  'blinkit_customer_feedback.csv',
#  'blinkit_delivery_performance.csv',
#  'blinkit_inventory.csv',
#  'blinkit_inventoryNew.csv',
#  'blinkit_marketing_performance.csv',
#  'blinkit_orders.csv',
#  'blinkit_order_items.csv',
#  'blinkit_products.csv',
#  'Category_Icons.xlsx',
#  'Rating_Icon.xlsx']

# %%
products = pd.read_csv("Blinkit_Dataset/blinkit_products.csv")

orders = pd.read_csv("Blinkit_Dataset/blinkit_orders.csv")

order_items = pd.read_csv("Blinkit_Dataset/blinkit_order_items.csv")

customers = pd.read_csv("Blinkit_Dataset/blinkit_customers.csv")

feedback = pd.read_csv("Blinkit_Dataset/blinkit_customer_feedback.csv")

marketing = pd.read_csv("Blinkit_Dataset/blinkit_marketing_performance.csv")

inventory = pd.read_csv("Blinkit_Dataset/blinkit_inventory.csv")

inventory_new = pd.read_csv("Blinkit_Dataset/blinkit_inventoryNew.csv")

delivery = pd.read_csv("Blinkit_Dataset/blinkit_delivery_performance.csv")

# %%
print(products.shape)
print(orders.shape)
print(order_items.shape)
print(customers.shape)
print(feedback.shape)
print(marketing.shape)
print(inventory.shape)
print(inventory_new.shape)
print(delivery.shape)
# Out:
# (268, 10)
# (5000, 10)
# (5000, 4)
# (2500, 11)
# (5000, 8)
# (5400, 11)
# (75172, 4)
# (18105, 4)
# (5000, 8)

# %%
products.info()
orders.info()
order_items.info()
customers.info()
feedback.info()
marketing.info()
inventory.info()
inventory_new.info()
delivery.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 268 entries, 0 to 267
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   product_id         268 non-null    int64
#  1   product_name       268 non-null    str
#  2   category           268 non-null    str
#  3   brand              268 non-null    str
#  4   price              268 non-null    float64
#  5   mrp                268 non-null    float64
#  6   margin_percentage  268 non-null    float64
#  7   shelf_life_days    268 non-null    int64
#  8   min_stock_level    268 non-null    int64
#  9   max_stock_level    268 non-null    int64
# dtypes: float64(3), int64(4), str(3)
# memory usage: 21.1 KB
# <class 'pandas.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   order_id                5000 non-null   int64
# ...

# %%
print(products.isnull().sum())

print(orders.isnull().sum())

print(order_items.isnull().sum())

print(customers.isnull().sum())

print(feedback.isnull().sum())

print(marketing.isnull().sum())

print(inventory.isnull().sum())

print(inventory_new.isnull().sum())

print(delivery.isnull().sum())
# Out:
# product_id           0
# product_name         0
# category             0
# brand                0
# price                0
# mrp                  0
# margin_percentage    0
# shelf_life_days      0
# min_stock_level      0
# max_stock_level      0
# dtype: int64
# order_id                  0
# customer_id               0
# order_date                0
# promised_delivery_time    0
# actual_delivery_time      0
# delivery_status           0
# order_total               0
# payment_method            0
# delivery_partner_id       0
# store_id                  0
# dtype: int64
# order_id      0
# product_id    0
# quantity      0
# unit_price    0
# dtype: int64
# customer_id          0
# customer_name        0
# email                0
# phone                0
# address              0
# area                 0
# pincode              0
# registration_date    0
# customer_segment     0
# total_orders         0
# avg_order_value      0
# dtype: int64
# feedback_id          0
# ...

# %%
print(products.duplicated().sum())

print(orders.duplicated().sum())

print(order_items.duplicated().sum())

print(customers.duplicated().sum())

print(feedback.duplicated().sum())

print(marketing.duplicated().sum())

print(inventory.duplicated().sum())

print(inventory_new.duplicated().sum())

print(delivery.duplicated().sum())
# Out:
# 0
# 0
# 0
# 0
# 0
# 0
# 0
# 7359
# 0

# %%
inventory_new = inventory_new.drop_duplicates()

# %%
inventory_new.duplicated().sum()
# Out:
# np.int64(0)

# %%
delivery.isnull().sum()
# Out:
# order_id                    0
# delivery_partner_id         0
# promised_time               0
# actual_time                 0
# delivery_time_minutes       0
# distance_km                 0
# delivery_status             0
# reasons_if_delayed       1902
# dtype: int64

# %%
delivery = delivery.fillna(delivery.median(numeric_only=True))

# %%
delivery = delivery.fillna("Unknown")

# %%
delivery.isnull().sum()
# Out:
# order_id                 0
# delivery_partner_id      0
# promised_time            0
# actual_time              0
# delivery_time_minutes    0
# distance_km              0
# delivery_status          0
# reasons_if_delayed       0
# dtype: int64

# %%
products.dtypes

orders.dtypes

order_items.dtypes

customers.dtypes

feedback.dtypes

marketing.dtypes

inventory.dtypes

inventory_new.dtypes

delivery.dtypes
# Out:
# order_id                   int64
# delivery_partner_id        int64
# promised_time                str
# actual_time                  str
# delivery_time_minutes    float64
# distance_km              float64
# delivery_status              str
# reasons_if_delayed           str
# dtype: object

# %%
products.describe(include="all")
# Out:
#            product_id product_name           category      brand       price  \
# count      268.000000          268                268        268  268.000000
# unique            NaN           51                 11        267         NaN
# top               NaN   Pet Treats  Dairy & Breakfast  Jha Group         NaN
# freq              NaN           12                 30          2         NaN
# mean    514855.940299          NaN                NaN        NaN  488.356828
# std     291391.529820          NaN                NaN        NaN  298.487200
# min       4452.000000          NaN                NaN        NaN   12.320000
# 25%     273697.750000          NaN                NaN        NaN  226.717500
# 50%     541459.000000          NaN                NaN        NaN  442.185000
# 75%     754334.000000          NaN                NaN        NaN  779.445000
# max     993331.000000          NaN                NaN        NaN  995.980000
#
# ...

# %%
orders.describe(include="all")
# Out:
#             order_id   customer_id           order_date  \
# count   5.000000e+03  5.000000e+03                 5000
# unique           NaN           NaN                 5000
# top              NaN           NaN  2024-07-17 08:34:01
# freq             NaN           NaN                    1
# mean    5.029129e+09  5.009685e+07                  NaN
# std     2.863533e+09  2.919082e+07                  NaN
# min     6.046500e+04  3.181300e+04                  NaN
# 25%     2.531421e+09  2.404314e+07                  NaN
# 50%     5.074378e+09  4.997808e+07                  NaN
# 75%     7.488579e+09  7.621215e+07                  NaN
# max     9.998298e+09  9.989390e+07                  NaN
#
#        promised_delivery_time actual_delivery_time delivery_status  \
# count                    5000                 5000            5000
# unique                   4999                 5000               3
# top       2024-10-13 14:06:50  2024-07-17 08:47:01         On Time
# ...

# %%
products.nunique()
orders.nunique()
customers.nunique()
# Out:
# customer_id          2500
# customer_name        2491
# email                2496
# phone                2500
# address              2500
# area                  316
# pincode              2494
# registration_date     589
# customer_segment        4
# total_orders           20
# avg_order_value      2487
# dtype: int64

# %%
orders.describe()
# Out:
#            order_id   customer_id  order_total  delivery_partner_id  \
# count  5.000000e+03  5.000000e+03   5000.00000          5000.000000
# mean   5.029129e+09  5.009685e+07   2201.86170         50050.318200
# std    2.863533e+09  2.919082e+07   1303.02438         28802.276922
# min    6.046500e+04  3.181300e+04     13.25000            43.000000
# 25%    2.531421e+09  2.404314e+07   1086.21500         24928.500000
# 50%    5.074378e+09  4.997808e+07   2100.69000         50262.500000
# 75%    7.488579e+09  7.621215e+07   3156.88250         74478.250000
# max    9.998298e+09  9.989390e+07   6721.46000         99968.000000
#
#           store_id
# count  5000.000000
# mean   4999.689000
# std    2886.089242
# min       1.000000
# 25%    2509.250000
# 50%    4987.000000
# 75%    7500.750000
# max    9995.000000

# %%
orders.select_dtypes(include="number").corr()
# Out:
#                      order_id  customer_id  order_total  delivery_partner_id  \
# order_id             1.000000    -0.008466    -0.008168             0.006545
# customer_id         -0.008466     1.000000     0.034951            -0.020232
# order_total         -0.008168     0.034951     1.000000            -0.003443
# delivery_partner_id  0.006545    -0.020232    -0.003443             1.000000
# store_id            -0.007966     0.002190    -0.023544             0.007138
#
#                      store_id
# order_id            -0.007966
# customer_id          0.002190
# order_total         -0.023544
# delivery_partner_id  0.007138
# store_id             1.000000

# %%
products["category"].value_counts()
# Out:
# category
# Dairy & Breakfast        30
# Fruits & Vegetables      27
# Snacks & Munchies        27
# Household Care           27
# Personal Care            25
# Pet Care                 25
# Pharmacy                 25
# Grocery & Staples        24
# Cold Drinks & Juices     22
# Instant & Frozen Food    20
# Baby Care                16
# Name: count, dtype: int64

# %%
customers.columns
# Out:
# Index(['customer_id', 'customer_name', 'email', 'phone', 'address', 'area',
#        'pincode', 'registration_date', 'customer_segment', 'total_orders',
#        'avg_order_value'],
#       dtype='str')

# %%
print(customers.columns.tolist())
# Out:
# ['customer_id', 'customer_name', 'email', 'phone', 'address', 'area', 'pincode', 'registration_date', 'customer_segment', 'total_orders', 'avg_order_value']

# %%
customers["area"].value_counts().head(10)
# Out:
# area
# Jalna          18
# Orai           17
# Bathinda       17
# Deoghar        17
# Ratlam         16
# Ghaziabad      16
# Kishanganj     15
# Nandyal        14
# Kadapa         14
# Gandhinagar    14
# Name: count, dtype: int64

# %%
customers["customer_segment"].value_counts()
# Out:
# customer_segment
# Regular     639
# Premium     633
# New         628
# Inactive    600
# Name: count, dtype: int64

# %%
customers["avg_order_value"].describe()
# Out:
# count    2500.000000
# mean     1102.375836
# std       523.043183
# min       200.430000
# 25%       631.817500
# 50%      1118.650000
# 75%      1565.400000
# max      1999.830000
# Name: avg_order_value, dtype: float64

# %%
customers["total_orders"].describe()
# Out:
# count    2500.000000
# mean       10.491600
# std         5.805533
# min         1.000000
# 25%         6.000000
# 50%        10.000000
# 75%        16.000000
# max        20.000000
# Name: total_orders, dtype: float64

# %%
products.head()
products.columns.tolist()
# Out:
# ['product_id',
#  'product_name',
#  'category',
#  'brand',
#  'price',
#  'mrp',
#  'margin_percentage',
#  'shelf_life_days',
#  'min_stock_level',
#  'max_stock_level']

# %%
orders.columns.tolist()
orders.head()
# Out:
#      order_id  customer_id           order_date promised_delivery_time  \
# 0  1961864118     30065862  2024-07-17 08:34:01    2024-07-17 08:52:01
# 1  1549769649      9573071  2024-05-28 13:14:29    2024-05-28 13:25:29
# 2  9185164487     45477575  2024-09-23 13:07:12    2024-09-23 13:25:12
# 3  9644738826     88067569  2023-11-24 16:16:56    2023-11-24 16:34:56
# 4  5427684290     83298567  2023-11-20 05:00:39    2023-11-20 05:17:39
#
#   actual_delivery_time delivery_status  order_total payment_method  \
# 0  2024-07-17 08:47:01         On Time      3197.07           Cash
# 1  2024-05-28 13:27:29         On Time       976.55           Cash
# 2  2024-09-23 13:29:12         On Time       839.05            UPI
# 3  2023-11-24 16:33:56         On Time       440.23           Card
# 4  2023-11-20 05:18:39         On Time      2526.68           Cash
#
#    delivery_partner_id  store_id
# 0                63230      4771
# 1                14983      7534
# ...

# %%
products.to_csv("products_clean.csv", index=False)
orders.to_csv("orders_clean.csv", index=False)
order_items.to_csv("order_items_clean.csv", index=False)
customers.to_csv("customers_clean.csv", index=False)
feedback.to_csv("feedback_clean.csv", index=False)
marketing.to_csv("marketing_clean.csv", index=False)
inventory.to_csv("inventory_clean.csv", index=False)
inventory_new.to_csv("inventoryNew_clean.csv", index=False)
delivery.to_csv("delivery_clean.csv", index=False)

# %%
[f for f in os.listdir() if "clean" in f.lower()]
# Out:
# ['Amazon_Cleaned.csv',
#  'Amazon_Cleaned.xlsx',
#  'Amazon_Cleaned_1.csv',
#  'Amazon_data_cleaning.ipynb',
#  'Blinkit_Cleaned.ipynb',
#  'customers_clean.csv',
#  'delivery_clean.csv',
#  'feedback_clean.csv',
#  'HR_Analytics_Cleaned.csv',
#  'inventoryNew_clean.csv',
#  'inventory_clean.csv',
#  'marketing_clean.csv',
#  'orders_clean.csv',
#  'order_items_clean.csv',
#  'products_clean.csv']
