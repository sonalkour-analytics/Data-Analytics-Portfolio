# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\monika\OneDrive\Desktop\flipkart_sales_enriched.csv")

# %%
df.head()
# Out:
#    Order ID      Product Name        Category  Price (INR)  Quantity Sold  \
# 0  ORD00001  Educational Book           Books     49069.56              2
# 1  ORD00002             Jeans        Clothing     12755.85              4
# 2  ORD00003        Face Cream          Beauty     11092.19              4
# 3  ORD00004        Smartwatch     Electronics     32657.81              1
# 4  ORD00005      Cookware Set  Home & Kitchen     26590.08              3
#
#    Total Sales (INR)  Order Date Payment Method  Customer Rating      Month  \
# 0           98139.12  2024-09-12     Debit Card              3.5  September
# 1           51023.40  2024-12-18            UPI              3.9   December
# 2           44368.76  2024-05-18     Debit Card              4.4        May
# 3           32657.81  2024-11-08     Debit Card              3.2   November
# 4           79770.24  2024-12-27            UPI              3.1   December
#
#    Year  Profit (INR)  Discount % Customer Segment Region
# ...

# %%
df.tail()
# Out:
#      Order ID  Product Name        Category  Price (INR)  Quantity Sold  \
# 995  ORD00996    Smartphone     Electronics     28995.81              3
# 996  ORD00997       Perfume          Beauty     32799.51              2
# 997  ORD00998    Face Cream          Beauty     40840.80              1
# 998  ORD00999  Cookware Set  Home & Kitchen     34741.79              4
# 999  ORD01000    Table Lamp  Home & Kitchen     16698.12              4
#
#      Total Sales (INR)  Order Date Payment Method  Customer Rating     Month  \
# 995           86987.43  2025-01-13            COD              5.0   January
# 996           65599.02  2024-12-18         Wallet              2.4  December
# 997           40840.80  2024-07-26            UPI              3.1      July
# 998          138967.16  2024-10-02    Net Banking              3.2   October
# 999           66792.48  2024-03-26    Credit Card              1.6     March
#
#      Year  Profit (INR)  Discount % Customer Segment Region
# ...

# %%
df.shape
# Out:
# (1000, 15)

# %%
df.columns
# Out:
# Index(['Order ID', 'Product Name', 'Category', 'Price (INR)', 'Quantity Sold',
#        'Total Sales (INR)', 'Order Date', 'Payment Method', 'Customer Rating',
#        'Month', 'Year', 'Profit (INR)', 'Discount %', 'Customer Segment',
#        'Region'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           1000 non-null   str
#  1   Product Name       1000 non-null   str
#  2   Category           1000 non-null   str
#  3   Price (INR)        1000 non-null   float64
#  4   Quantity Sold      1000 non-null   int64
#  5   Total Sales (INR)  1000 non-null   float64
#  6   Order Date         1000 non-null   str
#  7   Payment Method     1000 non-null   str
#  8   Customer Rating    1000 non-null   float64
#  9   Month              1000 non-null   str
#  10  Year               1000 non-null   int64
#  11  Profit (INR)       1000 non-null   float64
#  12  Discount %         1000 non-null   int64
#  13  Customer Segment   1000 non-null   str
#  14  Region             1000 non-null   str
# dtypes: float64(4), int64(3), str(8)
# memory usage: 117.3 KB

# %%
df.describe()
# Out:
#         Price (INR)  Quantity Sold  Total Sales (INR)  Customer Rating  \
# count   1000.000000    1000.000000        1000.000000      1000.000000
# mean   24520.258260       3.097000       75213.112740         3.011100
# std    14187.611227       1.410525       59457.598352         1.145408
# min      139.850000       1.000000         419.550000         1.000000
# 25%    12378.905000       2.000000       28581.765000         2.000000
# 50%    24650.015000       3.000000       57358.300000         3.100000
# 75%    35981.925000       4.000000      110618.595000         4.000000
# max    49911.750000       5.000000      243903.900000         5.000000
#
#               Year  Profit (INR)   Discount %
# count  1000.000000   1000.000000  1000.000000
# mean   2024.103000  15042.622548    17.699000
# std       0.304111  11891.519670     7.847801
# min    2024.000000     83.910000     5.000000
# 25%    2024.000000   5716.353000    11.000000
# 50%    2024.000000  11471.660000    18.000000
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# Order ID             0
# Product Name         0
# Category             0
# Price (INR)          0
# Quantity Sold        0
# Total Sales (INR)    0
# Order Date           0
# Payment Method       0
# Customer Rating      0
# Month                0
# Year                 0
# Profit (INR)         0
# Discount %           0
# Customer Segment     0
# Region               0
# dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.dtypes
# Out:
# Order ID                 str
# Product Name             str
# Category                 str
# Price (INR)          float64
# Quantity Sold          int64
# Total Sales (INR)    float64
# Order Date               str
# Payment Method           str
# Customer Rating      float64
# Month                    str
# Year                   int64
# Profit (INR)         float64
# Discount %             int64
# Customer Segment         str
# Region                   str
# dtype: object

# %%
df["Order Date"] = pd.to_datetime(df["Order Date"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           1000 non-null   str
#  1   Product Name       1000 non-null   str
#  2   Category           1000 non-null   str
#  3   Price (INR)        1000 non-null   float64
#  4   Quantity Sold      1000 non-null   int64
#  5   Total Sales (INR)  1000 non-null   float64
#  6   Order Date         1000 non-null   datetime64[us]
#  7   Payment Method     1000 non-null   str
#  8   Customer Rating    1000 non-null   float64
#  9   Month              1000 non-null   str
#  10  Year               1000 non-null   int64
#  11  Profit (INR)       1000 non-null   float64
#  12  Discount %         1000 non-null   int64
#  13  Customer Segment   1000 non-null   str
#  14  Region             1000 non-null   str
# dtypes: datetime64[us](1), float64(4), int64(3), str(7)
# ...

# %%
df["Day"] = df["Order Date"].dt.day

df["Month Name"] = df["Order Date"].dt.month_name()

df["Weekday"] = df["Order Date"].dt.day_name()

# %%
df["Category"].unique()
# Out:
# <StringArray>
# ['Books', 'Clothing', 'Beauty', 'Electronics', 'Home & Kitchen']
# Length: 5, dtype: str

# %%
df["Region"].unique()
# Out:
# <StringArray>
# ['West', 'North', 'South', 'East']
# Length: 4, dtype: str

# %%
df["Payment Method"].unique()
# Out:
# <StringArray>
# ['Debit Card', 'UPI', 'Wallet', 'COD', 'Credit Card', 'Net Banking']
# Length: 6, dtype: str

# %%
df["Category"].value_counts()
# Out:
# Category
# Electronics       217
# Books             209
# Home & Kitchen    193
# Beauty            192
# Clothing          189
# Name: count, dtype: int64

# %%
df["Region"].value_counts()
# Out:
# Region
# South    269
# North    259
# West     246
# East     226
# Name: count, dtype: int64

# %%
df["Payment Method"].value_counts()
# Out:
# Payment Method
# UPI            176
# Wallet         172
# Debit Card     171
# COD            169
# Net Banking    166
# Credit Card    146
# Name: count, dtype: int64

# %%
df.describe()
# Out:
#         Price (INR)  Quantity Sold  Total Sales (INR)  \
# count   1000.000000    1000.000000        1000.000000
# mean   24520.258260       3.097000       75213.112740
# min      139.850000       1.000000         419.550000
# 25%    12378.905000       2.000000       28581.765000
# 50%    24650.015000       3.000000       57358.300000
# 75%    35981.925000       4.000000      110618.595000
# max    49911.750000       5.000000      243903.900000
# std    14187.611227       1.410525       59457.598352
#
#                        Order Date  Customer Rating         Year  Profit (INR)  \
# count                        1000      1000.000000  1000.000000   1000.000000
# mean   2024-08-09 06:44:38.400000         3.011100  2024.103000  15042.622548
# min           2024-02-12 00:00:00         1.000000  2024.000000     83.910000
# 25%           2024-05-14 00:00:00         2.000000  2024.000000   5716.353000
# 50%           2024-08-06 12:00:00         3.100000  2024.000000  11471.660000
# ...

# %%
df.nlargest(10,"Total Sales (INR)")

df.nsmallest(10,"Total Sales (INR)")
# Out:
#      Order ID      Product Name        Category  Price (INR)  Quantity Sold  \
# 736  ORD00737        Hair Dryer          Beauty       139.85              3
# 536  ORD00537  Educational Book           Books       492.53              1
# 950  ORD00951           T-Shirt        Clothing       959.63              1
# 894  ORD00895            Tablet     Electronics      1002.29              1
# 522  ORD00523      Cookware Set  Home & Kitchen       218.58              5
# 289  ORD00290     Mixer Grinder  Home & Kitchen       464.18              3
# 458  ORD00459        Sofa Cover  Home & Kitchen      1549.63              1
# 937  ORD00938     Fiction Novel           Books       540.63              3
# 402  ORD00403        Comic Book           Books       904.29              2
# 591  ORD00592           Perfume          Beauty       462.00              4
#
#      Total Sales (INR) Order Date Payment Method  Customer Rating      Month  \
# ...

# %%
df.groupby("Product Name")["Quantity Sold"].sum().sort_values(ascending=False).head(10)
# Out:
# Product Name
# Educational Book    188
# Laptop              156
# Table Lamp          141
# Fiction Novel       138
# Smartwatch          137
# Headphones          135
# Lipstick            134
# Jeans               132
# T-Shirt             131
# Sneakers            125
# Name: Quantity Sold, dtype: int64

# %%
df.groupby("Product Name")["Total Sales (INR)"].sum().sort_values(ascending=False).head(10)
# Out:
# Product Name
# Educational Book    4522055.35
# Laptop              4132783.72
# Table Lamp          3986691.68
# Headphones          3722765.27
# Jeans               3685259.60
# Smartwatch          3680177.80
# Face Cream          3646816.97
# Perfume             3266905.75
# Fiction Novel       3172999.91
# Jacket              3161049.05
# Name: Total Sales (INR), dtype: float64

# %%
df.groupby("Category")["Profit (INR)"].sum().sort_values(ascending=False)
# Out:
# Category
# Electronics       3461434.614
# Clothing          3022877.372
# Books             2957151.930
# Beauty            2936116.810
# Home & Kitchen    2665041.822
# Name: Profit (INR), dtype: float64

# %%
df.groupby("Region")["Total Sales (INR)"].sum().sort_values(ascending=False)
# Out:
# Region
# North    20289991.87
# South    19862508.71
# West     18392767.90
# East     16667844.26
# Name: Total Sales (INR), dtype: float64

# %%
df.groupby("Category")["Customer Rating"].mean().sort_values(ascending=False)
# Out:
# Category
# Home & Kitchen    3.138860
# Books             3.079904
# Electronics       2.988479
# Clothing          2.971429
# Beauty            2.872396
# Name: Customer Rating, dtype: float64

# %%
df.groupby("Month")["Total Sales (INR)"].sum()
# Out:
# Month
# April        7334962.92
# August       5418893.98
# December     6491639.99
# February     5416573.21
# January      7160788.17
# July         7637324.95
# June         4992364.75
# March        6508879.04
# May          6706004.97
# November     5578535.08
# October      5702923.37
# September    6264222.31
# Name: Total Sales (INR), dtype: float64

# %%
df.groupby("Payment Method")["Total Sales (INR)"].sum()
# Out:
# Payment Method
# COD            12457136.55
# Credit Card    11155785.99
# Debit Card     12142559.04
# Net Banking    13219947.52
# UPI            12790919.48
# Wallet         13446764.16
# Name: Total Sales (INR), dtype: float64

# %%
df.groupby("Customer Segment")["Total Sales (INR)"].sum()
# Out:
# Customer Segment
# Online       25169884.13
# Retail       24311192.94
# Wholesale    25732035.67
# Name: Total Sales (INR), dtype: float64

# %%
df.groupby("Discount %")["Total Sales (INR)"].sum()
# Out:
# Discount %
# 5     4090145.54
# 6     2601357.99
# 7     4472626.31
# 8     2571978.60
# 9     3013884.87
# 10    2135668.06
# 11    2941281.88
# 12    2203716.23
# 13    2336372.21
# 14    2181612.89
# 15    2379601.14
# 16    3390797.10
# 17    2960664.33
# 18    2154538.58
# 19    3299050.69
# 20    2792909.42
# 21    2916633.13
# 22    1802171.20
# 23    2606472.15
# 24    2405651.47
# 25    3289021.52
# 26    2954640.77
# 27    3434644.08
# 28    2805072.57
# 29    2923101.22
# 30    4549498.79
# Name: Total Sales (INR), dtype: float64

# %%
df.corr(numeric_only=True)
# Out:
#                    Price (INR)  Quantity Sold  Total Sales (INR)  \
# Price (INR)           1.000000      -0.036321           0.728073
# Quantity Sold        -0.036321       1.000000           0.569006
# Total Sales (INR)     0.728073       0.569006           1.000000
# Customer Rating       0.008418      -0.015227          -0.004577
# Year                  0.018077       0.039692           0.050927
# Profit (INR)          0.728073       0.569006           1.000000
# Discount %            0.000374      -0.007126          -0.015656
# Day                  -0.023443       0.111025           0.049802
#
#                    Customer Rating      Year  Profit (INR)  Discount %  \
# Price (INR)               0.008418  0.018077      0.728073    0.000374
# Quantity Sold            -0.015227  0.039692      0.569006   -0.007126
# Total Sales (INR)        -0.004577  0.050927      1.000000   -0.015656
# Customer Rating           1.000000  0.013095     -0.004577    0.014337
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Order ID           1000 non-null   str
#  1   Product Name       1000 non-null   str
#  2   Category           1000 non-null   str
#  3   Price (INR)        1000 non-null   float64
#  4   Quantity Sold      1000 non-null   int64
#  5   Total Sales (INR)  1000 non-null   float64
#  6   Order Date         1000 non-null   datetime64[us]
#  7   Payment Method     1000 non-null   str
#  8   Customer Rating    1000 non-null   float64
#  9   Month              1000 non-null   str
#  10  Year               1000 non-null   int64
#  11  Profit (INR)       1000 non-null   float64
#  12  Discount %         1000 non-null   int64
#  13  Customer Segment   1000 non-null   str
#  14  Region             1000 non-null   str
#  15  Day                1000 non-null   int32
# ...

# %%
df.head()
# Out:
#    Order ID      Product Name        Category  Price (INR)  Quantity Sold  \
# 0  ORD00001  Educational Book           Books     49069.56              2
# 1  ORD00002             Jeans        Clothing     12755.85              4
# 2  ORD00003        Face Cream          Beauty     11092.19              4
# 3  ORD00004        Smartwatch     Electronics     32657.81              1
# 4  ORD00005      Cookware Set  Home & Kitchen     26590.08              3
#
#    Total Sales (INR) Order Date Payment Method  Customer Rating      Month  \
# 0           98139.12 2024-09-12     Debit Card              3.5  September
# 1           51023.40 2024-12-18            UPI              3.9   December
# 2           44368.76 2024-05-18     Debit Card              4.4        May
# 3           32657.81 2024-11-08     Debit Card              3.2   November
# 4           79770.24 2024-12-27            UPI              3.1   December
#
# ...

# %%
df.to_csv("flipkart_sales_cleaned.csv", index=False)
