# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\monika\OneDrive\Desktop\Amazon Sale Report.csv")

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel ship-service-level  Category Size Courier Status  \
# 0   Merchant     Amazon.in           Standard   T-shirt    S     On the Way
# 1   Merchant     Amazon.in           Standard     Shirt  3XL        Shipped
# 2     Amazon     Amazon.in          Expedited     Shirt   XL        Shipped
# 3   Merchant     Amazon.in           Standard   Blazzer    L     On the Way
# 4     Amazon     Amazon.in          Expedited  Trousers  3XL        Shipped
#
#    ...  currency  Amount    ship-city   ship-state ship-postal-code  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 21 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  str
#  2   Date                128976 non-null  str
#  3   Status              128976 non-null  str
#  4   Fulfilment          128976 non-null  str
#  5   Sales Channel       128976 non-null  str
#  6   ship-service-level  128976 non-null  str
#  7   Category            128976 non-null  str
#  8   Size                128976 non-null  str
#  9   Courier Status      128976 non-null  str
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  str
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  str
#  14  ship-state          128941 non-null  str
#  15  ship-postal-code    128941 non-null  float64
# ...

# %%
df.isnull() .sum()
# Out:
# index                      0
# Order ID                   0
# Date                       0
# Status                     0
# Fulfilment                 0
# Sales Channel              0
# ship-service-level         0
# Category                   0
# Size                       0
# Courier Status             0
# Qty                        0
# currency                7800
# Amount                  7800
# ship-city                 35
# ship-state                35
# ship-postal-code          35
# ship-country              35
# B2B                        0
# fulfilled-by           89713
# New                   128976
# PendingS              128976
# dtype: int64

# %%
df = df.drop(columns=["New", "PendingS"])

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 128976 entries, 0 to 128975
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128976 non-null  int64
#  1   Order ID            128976 non-null  str
#  2   Date                128976 non-null  str
#  3   Status              128976 non-null  str
#  4   Fulfilment          128976 non-null  str
#  5   Sales Channel       128976 non-null  str
#  6   ship-service-level  128976 non-null  str
#  7   Category            128976 non-null  str
#  8   Size                128976 non-null  str
#  9   Courier Status      128976 non-null  str
#  10  Qty                 128976 non-null  int64
#  11  currency            121176 non-null  str
#  12  Amount              121176 non-null  float64
#  13  ship-city           128941 non-null  str
#  14  ship-state          128941 non-null  str
#  15  ship-postal-code    128941 non-null  float64
# ...

# %%
df["fulfilled-by"].value_counts(dropna=False)
# Out:
# fulfilled-by
# NaN          89713
# Easy Ship    39263
# Name: count, dtype: int64

# %%
df["currency"].value_counts(dropna=False)
# Out:
# currency
# INR    121176
# NaN      7800
# Name: count, dtype: int64

# %%
df["Amount"].value_counts(dropna=False)
# Out:
# Amount
# NaN        7800
# 399.00     5439
# 771.00     2796
# 735.00     2436
# 0.00       2343
#            ...
# 719.05        1
# 829.52        1
# 708.58        1
# 1244.00       1
# 639.00        1
# Name: count, Length: 1409, dtype: int64

# %%
df[df["currency"].isnull()].head()
# Out:
#     index             Order ID      Date     Status Fulfilment Sales Channel  \
# 8       8  407-5443024-5233168  04-30-22  Cancelled     Amazon     Amazon.in
# 29     29  404-5933402-8801952  04-30-22  Cancelled   Merchant     Amazon.in
# 65     65  171-4137548-0481151  04-30-22  Cancelled     Amazon     Amazon.in
# 84     84  403-9950518-0349133  04-30-22  Cancelled     Amazon     Amazon.in
# 95     95  405-9112089-3379536  04-30-22  Cancelled     Amazon     Amazon.in
#
#    ship-service-level Category Size Courier Status  Qty currency  Amount  \
# 8           Expedited  T-shirt  3XL      Cancelled    0      NaN     NaN
# 29           Standard    Shirt  3XL     On the Way    0      NaN     NaN
# 65          Expedited    Shirt  XXL      Cancelled    0      NaN     NaN
# 84          Expedited    Shirt    M      Cancelled    0      NaN     NaN
# 95          Expedited    Shirt    L      Cancelled    0      NaN     NaN
#
# ...

# %%
df[df["Amount"].isnull()]["Status"].value_counts(dropna=False)
# Out:
# Status
# Cancelled                       7571
# Shipped                          208
# Shipped - Delivered to Buyer       8
# Shipping                           8
# Shipped - Returned to Seller       3
# Pending                            2
# Name: count, dtype: int64

# %%
df[(df["Status"] == "Shipped") & (df["Amount"].isnull())].head(10)
# Out:
#       index             Order ID      Date   Status Fulfilment Sales Channel  \
# 938     937  S02-5278980-4327051  04-30-22  Shipped     Amazon    Non-Amazon
# 1058   1057  S02-9107114-0460608  04-30-22  Shipped     Amazon    Non-Amazon
# 1616   1615  405-7790745-1369118  04-29-22  Shipped     Amazon     Amazon.in
# 1990   1989  171-9673855-2321133  04-29-22  Shipped     Amazon     Amazon.in
# 2425   2424  404-7478762-7926753  04-29-22  Shipped     Amazon     Amazon.in
# 2820   2819  404-0814480-8157169  04-29-22  Shipped     Amazon     Amazon.in
# 3632   3631  S02-1006261-5356758  04-28-22  Shipped     Amazon    Non-Amazon
# 3633   3632  S02-3681731-6111841  04-28-22  Shipped     Amazon    Non-Amazon
# 3635   3634  S02-1926028-4838217  04-28-22  Shipped     Amazon    Non-Amazon
# 3637   3636  S02-6828927-1180856  04-28-22  Shipped     Amazon    Non-Amazon
#
#      ship-service-level Category  Size Courier Status  Qty currency  Amount  \
# ...

# %%
df[(df["Amount"].isnull()) & (df["Qty"] > 0)].shape
# Out:
# (124, 19)

# %%
df[(df["Amount"].isnull()) & (df["Qty"] > 0)][
    ["Order ID", "Status", "Qty", "Amount", "currency", "Sales Channel"]
].head(20)
# Out:
#                   Order ID     Status  Qty  Amount currency Sales Channel
# 938    S02-5278980-4327051    Shipped   15     NaN      NaN    Non-Amazon
# 1058   S02-9107114-0460608    Shipped    2     NaN      NaN    Non-Amazon
# 3632   S02-1006261-5356758    Shipped    9     NaN      NaN    Non-Amazon
# 3633   S02-3681731-6111841    Shipped    1     NaN      NaN    Non-Amazon
# 3635   S02-1926028-4838217    Shipped    1     NaN      NaN    Non-Amazon
# 3637   S02-6828927-1180856    Shipped   13     NaN      NaN    Non-Amazon
# 3638   S02-3409426-0744131    Shipped    2     NaN      NaN    Non-Amazon
# 3887   S02-8357726-8633940    Shipped    1     NaN      NaN    Non-Amazon
# 3888   S02-6358630-3384547    Shipped    1     NaN      NaN    Non-Amazon
# 3889   S02-8920429-3367507    Shipped    1     NaN      NaN    Non-Amazon
# 3890   S02-0827522-8659612    Shipped    1     NaN      NaN    Non-Amazon
# 3891   S02-7924344-3280541    Shipped    1     NaN      NaN    Non-Amazon
# ...

# %%
df[df["Sales Channel"] == "Non-Amazon"]["Amount"].isnull().sum()
# Out:
# np.int64(124)

# %%
df.duplicated().sum()
# Out:
# np.int64(168)

# %%
duplicates = df[df.duplicated()]
duplicates.head(10)
# Out:
#      index             Order ID      Date                        Status  \
# 201      6  408-5748499-6859555  04-30-22                       Shipped
# 202      7  406-7807733-3785945  04-30-22  Shipped - Delivered to Buyer
# 203      8  407-5443024-5233168  04-30-22                     Cancelled
# 204      9  402-4393761-0311520  04-30-22                       Shipped
# 205     10  407-5633625-6970741  04-30-22                       Shipped
# 206     11  171-4638481-6326716  04-30-22                       Shipped
# 207     12  405-5513694-8146768  04-30-22  Shipped - Delivered to Buyer
# 208     13  408-7955685-3083534  04-30-22                       Shipped
# 616    539  408-1221783-1443515  04-30-22                       Shipped
# 617    540  404-3977029-4836363  04-30-22                     Cancelled
#
#     Fulfilment Sales Channel ship-service-level Category Size Courier Status  \
# 201     Amazon     Amazon.in          Expedited  T-shirt    L        Shipped
# ...

# %%
duplicates = df[df.duplicated(keep=False)]
duplicates.shape
# Out:
# (336, 19)

# %%
duplicates.head(20)
# Out:
#      index             Order ID      Date                        Status  \
# 6        6  408-5748499-6859555  04-30-22                       Shipped
# 7        7  406-7807733-3785945  04-30-22  Shipped - Delivered to Buyer
# 8        8  407-5443024-5233168  04-30-22                     Cancelled
# 9        9  402-4393761-0311520  04-30-22                       Shipped
# 10      10  407-5633625-6970741  04-30-22                       Shipped
# 11      11  171-4638481-6326716  04-30-22                       Shipped
# 12      12  405-5513694-8146768  04-30-22  Shipped - Delivered to Buyer
# 13      13  408-7955685-3083534  04-30-22                       Shipped
# 201      6  408-5748499-6859555  04-30-22                       Shipped
# 202      7  406-7807733-3785945  04-30-22  Shipped - Delivered to Buyer
# 203      8  407-5443024-5233168  04-30-22                     Cancelled
# 204      9  402-4393761-0311520  04-30-22                       Shipped
# ...

# %%
duplicates.iloc[0]
# Out:
# index                                   6
# Order ID              408-5748499-6859555
# Date                             04-30-22
# Status                            Shipped
# Fulfilment                         Amazon
# Sales Channel                   Amazon.in
# ship-service-level              Expedited
# Category                          T-shirt
# Size                                    L
# Courier Status                    Shipped
# Qty                                     1
# currency                              INR
# Amount                              653.0
# ship-city                      CHANDIGARH
# ship-state                     CHANDIGARH
# ship-postal-code                 160036.0
# ship-country                           IN
# B2B                                 False
# fulfilled-by                          NaN
# Name: 6, dtype: object

# %%
duplicates.iloc[1]
# Out:
# index                                            7
# Order ID                       406-7807733-3785945
# Date                                      04-30-22
# Status                Shipped - Delivered to Buyer
# Fulfilment                                Merchant
# Sales Channel                            Amazon.in
# ship-service-level                        Standard
# Category                                     Shirt
# Size                                             S
# Courier Status                             Shipped
# Qty                                              1
# currency                                       INR
# Amount                                       399.0
# ship-city                                HYDERABAD
# ship-state                               TELANGANA
# ship-postal-code                          500032.0
# ship-country                                    IN
# B2B                                          False
# ...

# %%
duplicates.sort_values("Order ID").head(20)
# Out:
#       index             Order ID      Date                        Status  \
# 1880   1879  171-0507987-9169958  04-29-22                       Shipped
# 2098   1879  171-0507987-9169958  04-29-22                       Shipped
# 6636   6274  171-2630358-5678736  04-26-22                       Shipped
# 6275   6274  171-2630358-5678736  04-26-22                       Shipped
# 6282   6281  171-2918708-7197155  04-26-22  Shipped - Delivered to Buyer
# 6643   6281  171-2918708-7197155  04-26-22  Shipped - Delivered to Buyer
# 6214   6213  171-3003328-2511523  04-26-22                     Cancelled
# 6575   6213  171-3003328-2511523  04-26-22                     Cancelled
# 6012   5705  171-3642547-9981136  04-27-22                       Shipped
# 5706   5705  171-3642547-9981136  04-27-22                       Shipped
# 6211   6210  171-3995208-9556366  04-26-22                       Shipped
# 6572   6210  171-3995208-9556366  04-26-22                       Shipped
# ...

# %%
df = df.drop_duplicates()

# %%
df.duplicated() .sum()
# Out:
# np.int64(0)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 128808 entries, 0 to 128975
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128808 non-null  int64
#  1   Order ID            128808 non-null  str
#  2   Date                128808 non-null  str
#  3   Status              128808 non-null  str
#  4   Fulfilment          128808 non-null  str
#  5   Sales Channel       128808 non-null  str
#  6   ship-service-level  128808 non-null  str
#  7   Category            128808 non-null  str
#  8   Size                128808 non-null  str
#  9   Courier Status      128808 non-null  str
#  10  Qty                 128808 non-null  int64
#  11  currency            121019 non-null  str
#  12  Amount              121019 non-null  float64
#  13  ship-city           128775 non-null  str
#  14  ship-state          128775 non-null  str
#  15  ship-postal-code    128775 non-null  float64
# ...

# %%
df["Date"] = pd.to_datetime(df["Date"])
# Out:
# C:\Users\monika\AppData\Local\Temp\ipykernel_10568\936118274.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Date"])

# %%
df["Date"] = pd.to_datetime(df["Date"], format="%m-%d-%y")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 128808 entries, 0 to 128975
# Data columns (total 19 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128808 non-null  int64
#  1   Order ID            128808 non-null  str
#  2   Date                128808 non-null  datetime64[us]
#  3   Status              128808 non-null  str
#  4   Fulfilment          128808 non-null  str
#  5   Sales Channel       128808 non-null  str
#  6   ship-service-level  128808 non-null  str
#  7   Category            128808 non-null  str
#  8   Size                128808 non-null  str
#  9   Courier Status      128808 non-null  str
#  10  Qty                 128808 non-null  int64
#  11  currency            121019 non-null  str
#  12  Amount              121019 non-null  float64
#  13  ship-city           128775 non-null  str
#  14  ship-state          128775 non-null  str
#  15  ship-postal-code    128775 non-null  float64
# ...

# %%
df["Year"] = df["Date"].dt.year
df["Month"] = df["Date"].dt.month_name()
df["Month No"] = df["Date"].dt.month
df["Day"] = df["Date"].dt.day
df["Weekday"] = df["Date"].dt.day_name()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 128808 entries, 0 to 128975
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   index               128808 non-null  int64
#  1   Order ID            128808 non-null  str
#  2   Date                128808 non-null  datetime64[us]
#  3   Status              128808 non-null  str
#  4   Fulfilment          128808 non-null  str
#  5   Sales Channel       128808 non-null  str
#  6   ship-service-level  128808 non-null  str
#  7   Category            128808 non-null  str
#  8   Size                128808 non-null  str
#  9   Courier Status      128808 non-null  str
#  10  Qty                 128808 non-null  int64
#  11  currency            121019 non-null  str
#  12  Amount              121019 non-null  float64
#  13  ship-city           128775 non-null  str
#  14  ship-state          128775 non-null  str
#  15  ship-postal-code    128775 non-null  float64
# ...

# %%
df[["Date","Year","Month","Month No","Day","Weekday"]].head()
# Out:
#         Date  Year  Month  Month No  Day   Weekday
# 0 2022-04-30  2022  April         4   30  Saturday
# 1 2022-04-30  2022  April         4   30  Saturday
# 2 2022-04-30  2022  April         4   30  Saturday
# 3 2022-04-30  2022  April         4   30  Saturday
# 4 2022-04-30  2022  April         4   30  Saturday

# %%
df["Amount"].describe()
# Out:
# count    121019.000000
# mean        648.631921
# std         281.224583
# min           0.000000
# 25%         449.000000
# 50%         605.000000
# 75%         788.000000
# max        5584.000000
# Name: Amount, dtype: float64

# %%
df[df["Amount"] == 0][["Order ID","Status","Qty","Category","Sales Channel"]].head(20)
# Out:
#                  Order ID                        Status  Qty Category  \
# 213   408-4547464-4180323  Shipped - Delivered to Buyer    1    Shirt
# 375   408-5020509-5674715  Shipped - Returned to Seller    1  Blazzer
# 386   408-3137526-3167563                       Shipped    1    Shirt
# 389   408-7971979-8745937  Shipped - Delivered to Buyer    1  Blazzer
# 393   408-0912805-7526753                       Shipped    1  T-shirt
# 437   408-6466311-6949931                       Shipped    1  T-shirt
# 442   408-6732772-4525113  Shipped - Delivered to Buyer    1  T-shirt
# 447   408-7937211-8974712                       Shipped    1  T-shirt
# 450   408-6348199-2089932                       Shipped    1  T-shirt
# 730   408-4193711-8156307  Shipped - Delivered to Buyer    1   Wallet
# 732   408-0902233-8069950  Shipped - Returned to Seller    1    Shirt
# 828   408-9407260-0749114                       Shipped    1    Shirt
# ...

# %%
(df["Amount"] == 0).sum()
# Out:
# np.int64(2340)

# %%
df[df["Amount"] == 0]["Category"].value_counts()
# Out:
# Category
# T-shirt     1012
# Shirt        856
# Blazzer      231
# Trousers     174
# Perfume       32
# Wallet        22
# Socks         12
# Shoes          1
# Name: count, dtype: int64

# %%
df[df["Amount"] == 0]["Fulfilment"].value_counts()
# Out:
# Fulfilment
# Amazon      1527
# Merchant     813
# Name: count, dtype: int64

# %%
df[df["Amount"] == 0]["Courier Status"].value_counts()
# Out:
# Courier Status
# Shipped      2314
# Unshipped      26
# Name: count, dtype: int64

# %%
df.to_csv("Amazon_Cleaned.csv", index=False)

# %%
df.shape
# Out:
# (128808, 24)

# %%
df["Amount"].sum()
# Out:
# np.float64(78496786.39)

# %%
df.groupby("Category")["Order ID"].nunique().sort_values(ascending=False)
# Out:
# Category
# T-shirt     47782
# Shirt       46499
# Blazzer     14984
# Trousers    10141
# Perfume      1146
# Wallet        897
# Socks         409
# Shoes         144
# Watch           2
# Name: Order ID, dtype: int64

# %%
df.groupby("Category")["Amount"].sum().sort_values(ascending=False)
# Out:
# Category
# T-shirt     39154132.17
# Shirt       21269768.70
# Blazzer     11208506.12
# Trousers     5341305.30
# Perfume       789419.66
# Wallet        458408.18
# Socks         150397.50
# Shoes         123933.76
# Watch            915.00
# Name: Amount, dtype: float64

# %%
df["Category"].value_counts()
# Out:
# Category
# T-shirt     50219
# Shirt       49804
# Blazzer     15489
# Trousers    10607
# Perfume      1157
# Wallet        926
# Socks         439
# Shoes         164
# Watch           3
# Name: count, dtype: int64

# %%
df.groupby("ship-state")["Amount"].sum().sort_values(ascending=False).head(10)
# Out:
# ship-state
# MAHARASHTRA       13318966.38
# KARNATAKA         10465387.03
# TELANGANA          6909670.08
# UTTAR PRADESH      6814126.08
# TAMIL NADU         6510503.73
# DELHI              4228503.97
# KERALA             3821997.58
# WEST BENGAL        3503223.44
# ANDHRA PRADESH     3214859.86
# HARYANA            2879146.99
# Name: Amount, dtype: float64

# %%
df.groupby("ship-city")["Amount"].sum().sort_values(ascending=False).head(10)
# Out:
# ship-city
# BENGALURU    6836614.65
# HYDERABAD    4941790.25
# MUMBAI       3696704.04
# NEW DELHI    3608277.78
# CHENNAI      3098745.74
# PUNE         2337978.18
# KOLKATA      1412815.87
# GURUGRAM     1220562.74
# THANE        1003878.29
# LUCKNOW       933926.34
# Name: Amount, dtype: float64

# %%
df.groupby("Status")["Amount"].sum().sort_values(ascending=False)
# Out:
# Status
# Shipped                          50268420.00
# Shipped - Delivered to Buyer     18619610.00
# Cancelled                         6910831.39
# Shipped - Returned to Seller      1269245.00
# Shipped - Picked Up                661252.00
# Pending                            430271.00
# Pending - Waiting for Pick Up      192138.00
# Shipped - Returning to Seller      107620.00
# Shipped - Out for Delivery          26971.00
# Shipped - Rejected by Buyer          7295.00
# Shipped - Lost in Transit            1997.00
# Shipped - Damaged                    1136.00
# Shipping                                0.00
# Name: Amount, dtype: float64

# %%
df.groupby("Fulfilment")["Amount"].sum().sort_values(ascending=False)
# Out:
# Fulfilment
# Amazon      54262165.00
# Merchant    24234621.39
# Name: Amount, dtype: float64

# %%
df["Fulfilment"].value_counts()
# Out:
# Fulfilment
# Amazon      89595
# Merchant    39213
# Name: count, dtype: int64

# %%
df.groupby("Sales Channel")["Amount"].sum()
# Out:
# Sales Channel
# Amazon.in     78496786.39
# Non-Amazon           0.00
# Name: Amount, dtype: float64

# %%
df["Sales Channel"].value_counts()
# Out:
# Sales Channel
# Amazon.in     128684
# Non-Amazon       124
# Name: count, dtype: int64

# %%
df.groupby("B2B")["Amount"].sum()
# Out:
# B2B
# False    77905565.60
# True       591220.79
# Name: Amount, dtype: float64

# %%
df["B2B"].value_counts()
# Out:
# B2B
# False    127937
# True        871
# Name: count, dtype: int64

# %%
df.groupby("Courier Status")["Amount"].sum().sort_values(ascending=False)
# Out:
# Courier Status
# Shipped       70971225.00
# Unshipped      4339691.00
# On the Way     3185870.39
# Cancelled            0.00
# Name: Amount, dtype: float64

# %%
df.to_csv("Amazon_Cleaned.csv", index=False)

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\monika
# ...
